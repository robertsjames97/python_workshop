# %%
def fahr_to_celsius(temp):
    return (temp-32) * 5/9

# %%
fahr_to_celsius(32)
# Out:
# 0.0

# %%
5 + fahr_to_celsius(32)
# Out:
# 5.0

# %%
print("Boiling temperature of water:", fahr_to_celsius(212))
# Out:
# Boiling temperature of water: 100.0

# %%
def celsius_to_kelvin(temp):
    return temp + 273.15

# %%
def fahr_to_kelvin(temp_f):
    temp_c = fahr_to_celsius(temp_f)
    temp_k = celsius_to_kelvin(temp_c)
    return temp_k

# %%
fahr_to_kelvin(32)
# Out:
# 273.15

# %%
def visualise(filename):
    
    data = np.loadtxt(fname=filename, delimiter=',')

    fig = matplotlib.pyplot.figure(figsize=(5, 10))

    axes1 = fig.add_subplot(3, 1, 1)
    axes2 = fig.add_subplot(3, 1, 2)
    axes3 = fig.add_subplot(3, 1, 3)

    axes1.set_ylabel('average')
    axes1.plot(data.mean(axis=0))

    axes2.set_ylabel('max')
    axes2.plot(data.max(axis=0))

    axes3.set_ylabel('min')
    axes3.set_ylim(0,6)
    axes3.plot(data.min(axis=0))

    fig.tight_layout()
    matplotlib.pyplot.show()

# %%
def detect_problems(filename):
    
    data = np.loadtxt(fname=filename, delimiter=',')
    
    if data.max(axis=0)[0] == 0 and data.max(axis=0)[20] == 20:
        print("Suspicious looking maxima")
    elif data.min(axis=0).sum() == 0:
        print("Minima add up to zero")
    else:
        print("Seems okay!")

# %%
# %matplotlib inline

# %%
import glob

# %%
import numpy as np
import matplotlib.pyplot

# %%
filenames = sorted(glob.glob("data/inflammation*.csv"))

for f in filenames[:3]:
    print(f)
    visualise(f)
    detect_problems(f)
# Out:
# data/inflammation-01.csv
# Suspicious looking maxima
# data/inflammation-02.csv
# Suspicious looking maxima
# data/inflammation-03.csv
# Minima add up to zero

# %%
def offset_mean(data, target_mean_value):
    return (data - data.mean()) + target_mean_value

# %%
z = np.zeros((2, 2))
print(offset_mean(z, 3))
# Out:
# [[ 3.  3.]
#  [ 3.  3.]]

# %%
data = np.loadtxt(fname="data/inflammation-01.csv", delimiter = ",")

# %%
print(offset_mean(data, 0.0))
# Out:
# [[-6.14875 -6.14875 -5.14875 ..., -3.14875 -6.14875 -6.14875]
#  [-6.14875 -5.14875 -4.14875 ..., -5.14875 -6.14875 -5.14875]
#  [-6.14875 -5.14875 -5.14875 ..., -4.14875 -5.14875 -5.14875]
#  ...,
#  [-6.14875 -5.14875 -5.14875 ..., -5.14875 -5.14875 -5.14875]
#  [-6.14875 -6.14875 -6.14875 ..., -6.14875 -4.14875 -6.14875]
#  [-6.14875 -6.14875 -5.14875 ..., -5.14875 -5.14875 -6.14875]]

# %%
print("Original min, mean, max:", data.min(), data.mean(), data.max())
offset_data = offset_mean(data, 0.0)
print("Offset min, mean, max:", offset_data.min(), offset_data.mean(), offset_data.max())
# Out:
# Original min, mean, max: 0.0 6.14875 20.0
# Offset min, mean, max: -6.14875 2.84217094304e-16 13.85125

# %%
print("standard dev before:", data.std())
print("standard dev after:", offset_data.std())
# Out:
# standard dev before: 4.61383319712
# standard dev after: 4.61383319712

# %%
print("Difference in standard dev:", data.std() - offset_data.std())
# Out:
# Difference in standard dev: 0.0

# %%
def offset_mean(data, target_mean_value):
    """This is my function that offsets the mean.
    Example: offset_mean([1, 2, 3], 0) => [-1, 0, 1]
    """
    return (data - np.mean(data)) + target_mean_value

# %%
help(offset_mean)
# Out:
# Help on function offset_mean in module __main__:
#
# offset_mean(data, target_mean_value)
#     This is my function that offsets the mean.
#     Example: offset_mean([1, 2, 3], 0) => [-1, 0, 1]

# %%
def offset_mean(data, target_mean_value = 0.0):
    """This is my function that offsets the mean.
    Example: offset_mean([1, 2, 3], 0) => [-1, 0, 1]
    """
    return (data - np.mean(data)) + target_mean_value

# %%
offset_mean([1, 2, 3], 0)
# Out:
# array([-1.,  0.,  1.])

# %%
offset_mean([1, 2, 3], 10)
# Out:
# array([  9.,  10.,  11.])

# %%
offset_mean([1, 2, 3])
# Out:
# array([-1.,  0.,  1.])

# %%
def display(a=1, b=2, c=3):
    print("a:", a, "b:", b, "c:", c)

# %%
display()
# Out:
# a: 1 b: 2 c: 3

# %%
display(4,5,6)
# Out:
# a: 4 b: 5 c: 6

# %%
display(4,5)
# Out:
# a: 4 b: 5 c: 3

# %%
display(c=66)
# Out:
# a: 1 b: 2 c: 66
